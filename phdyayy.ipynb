# %% [markdown]
# <a href="https://colab.research.google.com/github/medha-mannem/pothole-detection/blob/main/phdyayy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.applications import MobileNet
from google.colab import drive
import tensorflow as tf
import cv2
import seaborn as sns
import os

# %%
# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Define the ImageDataGenerator for training and testing
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

test_datagen = ImageDataGenerator(rescale=1./255)

# %%
# Path to your training and testing directories
train_dir = '/content/drive/MyDrive/phdimages/train'
test_dir = '/content/drive/MyDrive/phdimages/validation'

# %%
# Create training and testing sets
training_set = train_datagen.flow_from_directory(
    train_dir,
    target_size=(64, 64),
    batch_size=32,
    class_mode='binary'
)

test_set = test_datagen.flow_from_directory(
    test_dir,
    target_size=(64, 64),
    batch_size=32,
    class_mode='binary'
)
# Out:
# Found 4538 images belonging to 2 classes.
# Found 681 images belonging to 2 classes.

# %%
# Calculate steps_per_epoch and validation_steps
train_steps_per_epoch = training_set.samples // training_set.batch_size
val_steps = test_set.samples // test_set.batch_size

# %%
# Define the distribution strategy
strategy = tf.distribute.MirroredStrategy()

with strategy.scope():
    # Define the model using MobileNet
    base_model = MobileNet(input_shape=(64, 64, 3), include_top=False, weights='imagenet')
    classifier = Sequential([
        base_model,
        Flatten(),
        Dense(units=128, activation='relu'),
        Dropout(0.5),
        Dense(units=1, activation='sigmoid')
    ])

    # Compile the model with additional metrics
    classifier.compile(optimizer='adam', loss='binary_crossentropy',
                       metrics=['accuracy',
                                tf.keras.metrics.Precision(name='precision'),
                                tf.keras.metrics.Recall(name='recall'),
                                tf.keras.metrics.AUC(name='auc')])
# Out:
# <ipython-input-7-9e29349ea05f>:6: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = MobileNet(input_shape=(64, 64, 3), include_top=False, weights='imagenet')
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17225924/17225924 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Train the model
history = classifier.fit(
    training_set,
    steps_per_epoch=train_steps_per_epoch,
    epochs=75,
    validation_data=test_set,
    validation_steps=val_steps
)
# Out:
# Epoch 1/75
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1034s 7s/step - accuracy: 0.8947 - auc: 0.9484 - loss: 0.3711 - precision: 0.8868 - recall: 0.8719 - val_accuracy: 0.9568 - val_auc: 0.9904 - val_loss: 0.1890 - val_precision: 0.9966 - val_recall: 0.9136
# Epoch 2/75
#   1/141 ━━━━━━━━━━━━━━━━━━━━ 2:06 902ms/step - accuracy: 0.9688 - auc: 1.0000 - loss: 0.0574 - precision: 0.9375 - recall: 1.0000
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 60s 424ms/step - accuracy: 0.9688 - auc: 1.0000 - loss: 0.0574 - precision: 0.9375 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0062 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 3/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 167s 1s/step - accuracy: 0.9735 - auc: 0.9951 - loss: 0.0837 - precision: 0.9759 - recall: 0.9686 - val_accuracy: 0.9688 - val_auc: 0.9924 - val_loss: 0.1479 - val_precision: 0.9810 - val_recall: 0.9537
# Epoch 4/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.9375 - auc: 1.0000 - loss: 0.1217 - precision: 1.0000 - recall: 0.8889 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0016 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 5/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 165s 1s/step - accuracy: 0.9796 - auc: 0.9966 - loss: 0.0613 - precision: 0.9767 - recall: 0.9816 - val_accuracy: 0.7842 - val_auc: 0.9411 - val_loss: 1.2753 - val_precision: 0.6916 - val_recall: 0.9969
# Epoch 6/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 566us/step - accuracy: 0.9688 - auc: 1.0000 - loss: 0.0605 - precision: 1.0000 - recall: 0.9474 - val_accuracy: 0.7778 - val_auc: 0.7500 - val_loss: 1.7443 - val_precision: 0.7143 - val_recall: 1.0000
# Epoch 7/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 164s 1s/step - accuracy: 0.9779 - auc: 0.9959 - loss: 0.0715 - precision: 0.9734 - recall: 0.9808 - val_accuracy: 0.9792 - val_auc: 0.9954 - val_loss: 0.1065 - val_precision: 0.9844 - val_recall: 0.9722
# Epoch 8/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 542us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0044 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0163 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 9/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 172s 1s/step - accuracy: 0.9779 - auc: 0.9965 - loss: 0.0673 - precision: 0.9733 - recall: 0.9810 - val_accuracy: 0.9583 - val_auc: 0.9956 - val_loss: 0.1102 - val_precision: 0.9306 - val_recall: 0.9877
# Epoch 10/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 627us/step - accuracy: 0.9375 - auc: 0.9686 - loss: 0.2990 - precision: 0.8824 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0123 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 11/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 167s 1s/step - accuracy: 0.9854 - auc: 0.9981 - loss: 0.0413 - precision: 0.9834 - recall: 0.9865 - val_accuracy: 0.9792 - val_auc: 0.9918 - val_loss: 0.1014 - val_precision: 1.0000 - val_recall: 0.9573
# Epoch 12/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 528us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0179 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 1.1745e-05 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 13/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 201s 1s/step - accuracy: 0.9852 - auc: 0.9970 - loss: 0.0548 - precision: 0.9839 - recall: 0.9855 - val_accuracy: 0.9836 - val_auc: 0.9962 - val_loss: 0.0909 - val_precision: 0.9786 - val_recall: 0.9877
# Epoch 14/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 523us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0358 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 1.8972e-04 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 15/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 205s 1s/step - accuracy: 0.9869 - auc: 0.9980 - loss: 0.0465 - precision: 0.9836 - recall: 0.9887 - val_accuracy: 0.9807 - val_auc: 0.9974 - val_loss: 0.0472 - val_precision: 0.9875 - val_recall: 0.9724
# Epoch 16/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0139 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0233 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 17/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 165s 1s/step - accuracy: 0.9896 - auc: 0.9993 - loss: 0.0260 - precision: 0.9881 - recall: 0.9893 - val_accuracy: 0.9792 - val_auc: 0.9953 - val_loss: 0.0769 - val_precision: 0.9785 - val_recall: 0.9785
# Epoch 18/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.9375 - auc: 0.9961 - loss: 0.1350 - precision: 1.0000 - recall: 0.8750 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0057 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 19/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 168s 1s/step - accuracy: 0.9883 - auc: 0.9977 - loss: 0.0452 - precision: 0.9905 - recall: 0.9851 - val_accuracy: 0.9747 - val_auc: 0.9949 - val_loss: 0.1084 - val_precision: 0.9611 - val_recall: 0.9877
# Epoch 20/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - accuracy: 0.9688 - auc: 1.0000 - loss: 0.0340 - precision: 0.9500 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 1.2292e-06 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 21/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 199s 1s/step - accuracy: 0.9924 - auc: 0.9990 - loss: 0.0275 - precision: 0.9909 - recall: 0.9937 - val_accuracy: 0.9673 - val_auc: 0.9989 - val_loss: 0.0723 - val_precision: 0.9415 - val_recall: 0.9938
# Epoch 22/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 567us/step - accuracy: 0.9688 - auc: 1.0000 - loss: 0.0397 - precision: 1.0000 - recall: 0.9444 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 6.1240e-06 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 23/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 168s 1s/step - accuracy: 0.9887 - auc: 0.9978 - loss: 0.0416 - precision: 0.9887 - recall: 0.9874 - val_accuracy: 0.9717 - val_auc: 0.9988 - val_loss: 0.0636 - val_precision: 0.9501 - val_recall: 0.9939
# Epoch 24/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 578us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0033 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0092 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 25/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 167s 1s/step - accuracy: 0.9948 - auc: 0.9993 - loss: 0.0213 - precision: 0.9959 - recall: 0.9934 - val_accuracy: 0.9643 - val_auc: 0.9945 - val_loss: 0.1538 - val_precision: 0.9935 - val_recall: 0.9325
# Epoch 26/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.9688 - auc: 1.0000 - loss: 0.1653 - precision: 1.0000 - recall: 0.9444 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 3.7077e-04 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 27/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 167s 1s/step - accuracy: 0.9895 - auc: 0.9995 - loss: 0.0229 - precision: 0.9867 - recall: 0.9924 - val_accuracy: 0.9836 - val_auc: 0.9980 - val_loss: 0.0557 - val_precision: 0.9758 - val_recall: 0.9908
# Epoch 28/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 530us/step - accuracy: 0.9688 - auc: 1.0000 - loss: 0.0628 - precision: 0.9231 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 1.8616e-04 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 29/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 172s 1s/step - accuracy: 0.9938 - auc: 0.9998 - loss: 0.0118 - precision: 0.9902 - recall: 0.9969 - val_accuracy: 0.9777 - val_auc: 0.9973 - val_loss: 0.0765 - val_precision: 0.9639 - val_recall: 0.9907
# Epoch 30/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 528us/step - accuracy: 0.9688 - auc: 1.0000 - loss: 0.0244 - precision: 1.0000 - recall: 0.9333 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0011 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 31/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 168s 1s/step - accuracy: 0.9939 - auc: 0.9994 - loss: 0.0233 - precision: 0.9945 - recall: 0.9931 - val_accuracy: 0.9851 - val_auc: 0.9933 - val_loss: 0.1656 - val_precision: 0.9937 - val_recall: 0.9753
# Epoch 32/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 648us/step - accuracy: 0.9688 - auc: 1.0000 - loss: 0.0793 - precision: 0.9167 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 8.8931e-05 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 33/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 168s 1s/step - accuracy: 0.9932 - auc: 0.9980 - loss: 0.0255 - precision: 0.9921 - recall: 0.9939 - val_accuracy: 0.9821 - val_auc: 0.9948 - val_loss: 0.0842 - val_precision: 0.9729 - val_recall: 0.9908
# Epoch 34/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.9688 - auc: 0.9750 - loss: 0.2137 - precision: 0.9231 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0013 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 35/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 168s 1s/step - accuracy: 0.9933 - auc: 0.9999 - loss: 0.0158 - precision: 0.9936 - recall: 0.9927 - val_accuracy: 0.9807 - val_auc: 0.9957 - val_loss: 0.0657 - val_precision: 0.9874 - val_recall: 0.9721
# Epoch 36/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 544us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 4.1360e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8889 - val_auc: 1.0000 - val_loss: 0.2186 - val_precision: 1.0000 - val_recall: 0.8333
# Epoch 37/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 168s 1s/step - accuracy: 0.9933 - auc: 0.9992 - loss: 0.0267 - precision: 0.9944 - recall: 0.9918 - val_accuracy: 0.9330 - val_auc: 0.9880 - val_loss: 0.2276 - val_precision: 1.0000 - val_recall: 0.8611
# Epoch 38/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0084 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8889 - val_auc: 1.0000 - val_loss: 0.2278 - val_precision: 1.0000 - val_recall: 0.8000
# Epoch 39/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 169s 1s/step - accuracy: 0.9933 - auc: 0.9994 - loss: 0.0241 - precision: 0.9915 - recall: 0.9950 - val_accuracy: 0.9836 - val_auc: 0.9975 - val_loss: 0.0553 - val_precision: 0.9846 - val_recall: 0.9815
# Epoch 40/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 7.4470e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0031 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 41/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 169s 1s/step - accuracy: 0.9847 - auc: 0.9980 - loss: 0.0510 - precision: 0.9824 - recall: 0.9855 - val_accuracy: 0.9777 - val_auc: 0.9915 - val_loss: 0.2035 - val_precision: 0.9843 - val_recall: 0.9690
# Epoch 42/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 542us/step - accuracy: 0.9688 - auc: 1.0000 - loss: 0.0484 - precision: 0.9091 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0470 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 43/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 167s 1s/step - accuracy: 0.9891 - auc: 0.9981 - loss: 0.0384 - precision: 0.9861 - recall: 0.9912 - val_accuracy: 0.9777 - val_auc: 0.9960 - val_loss: 0.0832 - val_precision: 0.9670 - val_recall: 0.9877
# Epoch 44/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 845us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0042 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0053 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 45/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 200s 1s/step - accuracy: 0.9960 - auc: 0.9998 - loss: 0.0140 - precision: 0.9966 - recall: 0.9949 - val_accuracy: 0.9732 - val_auc: 0.9977 - val_loss: 0.0781 - val_precision: 0.9935 - val_recall: 0.9506
# Epoch 46/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 821us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0298 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0404 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 47/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 203s 1s/step - accuracy: 0.9879 - auc: 0.9990 - loss: 0.0340 - precision: 0.9865 - recall: 0.9882 - val_accuracy: 0.9479 - val_auc: 0.9937 - val_loss: 0.1413 - val_precision: 0.9931 - val_recall: 0.8975
# Epoch 48/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0236 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8889 - val_auc: 1.0000 - val_loss: 0.0872 - val_precision: 1.0000 - val_recall: 0.8571
# Epoch 49/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 198s 1s/step - accuracy: 0.9931 - auc: 0.9993 - loss: 0.0195 - precision: 0.9925 - recall: 0.9931 - val_accuracy: 0.9896 - val_auc: 0.9961 - val_loss: 0.0551 - val_precision: 0.9969 - val_recall: 0.9817
# Epoch 50/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - accuracy: 0.9688 - auc: 1.0000 - loss: 0.0420 - precision: 1.0000 - recall: 0.9500 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0136 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 51/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 167s 1s/step - accuracy: 0.9927 - auc: 0.9990 - loss: 0.0215 - precision: 0.9910 - recall: 0.9938 - val_accuracy: 0.9851 - val_auc: 0.9961 - val_loss: 0.0537 - val_precision: 0.9817 - val_recall: 0.9877
# Epoch 52/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0214 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 5.3527e-05 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 53/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 169s 1s/step - accuracy: 0.9947 - auc: 0.9992 - loss: 0.0170 - precision: 0.9938 - recall: 0.9948 - val_accuracy: 0.9866 - val_auc: 0.9994 - val_loss: 0.0332 - val_precision: 0.9848 - val_recall: 0.9878
# Epoch 54/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 525us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 1.2508e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0031 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 55/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 167s 1s/step - accuracy: 0.9966 - auc: 0.9998 - loss: 0.0134 - precision: 0.9969 - recall: 0.9961 - val_accuracy: 0.9702 - val_auc: 0.9974 - val_loss: 0.0699 - val_precision: 0.9474 - val_recall: 0.9939
# Epoch 56/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 535us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 3.8609e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8889 - val_auc: 0.9167 - val_loss: 0.7304 - val_precision: 0.7500 - val_recall: 1.0000
# Epoch 57/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 168s 1s/step - accuracy: 0.9964 - auc: 0.9997 - loss: 0.0110 - precision: 0.9973 - recall: 0.9952 - val_accuracy: 0.9688 - val_auc: 0.9964 - val_loss: 0.0973 - val_precision: 0.9967 - val_recall: 0.9385
# Epoch 58/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 829us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0317 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0062 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 59/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 201s 1s/step - accuracy: 0.9939 - auc: 0.9986 - loss: 0.0282 - precision: 0.9940 - recall: 0.9931 - val_accuracy: 0.9777 - val_auc: 0.9960 - val_loss: 0.1613 - val_precision: 0.9614 - val_recall: 0.9939
# Epoch 60/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.9688 - auc: 1.0000 - loss: 0.0815 - precision: 1.0000 - recall: 0.9333 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0030 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 61/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 169s 1s/step - accuracy: 0.9871 - auc: 0.9987 - loss: 0.0411 - precision: 0.9877 - recall: 0.9851 - val_accuracy: 0.9717 - val_auc: 0.9947 - val_loss: 0.0878 - val_precision: 0.9497 - val_recall: 0.9938
# Epoch 62/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 567us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0091 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8889 - val_auc: 1.0000 - val_loss: 0.2930 - val_precision: 0.8571 - val_recall: 1.0000
# Epoch 63/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 201s 1s/step - accuracy: 0.9931 - auc: 0.9997 - loss: 0.0214 - precision: 0.9933 - recall: 0.9920 - val_accuracy: 0.9836 - val_auc: 0.9979 - val_loss: 0.0465 - val_precision: 0.9969 - val_recall: 0.9694
# Epoch 64/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 585us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0013 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 1.7313e-05 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 65/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 200s 1s/step - accuracy: 0.9975 - auc: 0.9999 - loss: 0.0083 - precision: 0.9975 - recall: 0.9973 - val_accuracy: 0.9940 - val_auc: 0.9982 - val_loss: 0.0224 - val_precision: 0.9969 - val_recall: 0.9908
# Epoch 66/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - accuracy: 0.9688 - auc: 1.0000 - loss: 0.0447 - precision: 0.9167 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0034 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 67/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 199s 1s/step - accuracy: 0.9990 - auc: 0.9999 - loss: 0.0051 - precision: 0.9986 - recall: 0.9993 - val_accuracy: 0.9688 - val_auc: 0.9980 - val_loss: 0.0940 - val_precision: 1.0000 - val_recall: 0.9354
# Epoch 68/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 802us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0142 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 2.4438e-04 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 69/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 200s 1s/step - accuracy: 0.9963 - auc: 0.9996 - loss: 0.0133 - precision: 0.9961 - recall: 0.9961 - val_accuracy: 0.9926 - val_auc: 0.9982 - val_loss: 0.0307 - val_precision: 1.0000 - val_recall: 0.9848
# Epoch 70/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 550us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 5.7726e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0018 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 71/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 200s 1s/step - accuracy: 0.9967 - auc: 0.9999 - loss: 0.0092 - precision: 0.9974 - recall: 0.9959 - val_accuracy: 0.9911 - val_auc: 0.9976 - val_loss: 0.0412 - val_precision: 0.9938 - val_recall: 0.9877
# Epoch 72/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 878us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0191 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0022 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 73/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 202s 1s/step - accuracy: 0.9979 - auc: 0.9997 - loss: 0.0086 - precision: 0.9977 - recall: 0.9980 - val_accuracy: 0.9747 - val_auc: 0.9952 - val_loss: 0.0996 - val_precision: 1.0000 - val_recall: 0.9477
# Epoch 74/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 884us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0019 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0023 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 75/75
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 201s 1s/step - accuracy: 0.9996 - auc: 1.0000 - loss: 0.0014 - precision: 1.0000 - recall: 0.9992 - val_accuracy: 0.9940 - val_auc: 0.9968 - val_loss: 0.0360 - val_precision: 0.9969 - val_recall: 0.9907

# %%
# Function to predict image and highlight potholes
def predict_and_draw(imgpath):
    try:
        # Load and preprocess the image
        predict_image = load_img(imgpath, target_size=(64, 64))
        predict_image_array = img_to_array(predict_image)
        predict_image_array = np.expand_dims(predict_image_array, axis=0) / 255.0

        # Predict the class
        result = classifier.predict(predict_image_array)

        # Convert image back to original size
        img = cv2.imread(imgpath)
        img = cv2.resize(img, (64, 64))

        # Draw bounding box if a pothole is detected
        if result[0][0] >= 0.5:
            print("Pothole detected!")
            # For simplicity, use a dummy bounding box
            x, y, w, h = 10, 10, 50, 50  # Replace with actual bounding box coordinates if available
            cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)
            output_path = '/content/drive/MyDrive/predictions/' + os.path.basename(imgpath)
            cv2.imwrite(output_path, img)
            plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
            plt.title("Pothole detected")
        else:
            print("No Pothole detected.")
            plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
            plt.title("No Pothole detected")

        plt.show()
    except Exception as e:
        print(f"Error occurred: {e}")

# %%
# Plot training & validation accuracy and loss values
plt.figure(figsize=(12, 8))

# %%
# Accuracy
plt.subplot(2, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# %%
# Loss
plt.subplot(2, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# %%
# Precision
plt.subplot(2, 2, 3)
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('Model precision')
plt.ylabel('Precision')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# %%
# Recall
plt.subplot(2, 2, 4)
plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])
plt.title('Model recall')
plt.ylabel('Recall')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# %%
plt.tight_layout()
plt.show()

# %%
# Generate confusion matrix
def plot_confusion_matrix():
    Y_pred = classifier.predict(test_set)
    y_pred = np.round(Y_pred).astype(int)
    y_true = test_set.classes

    cm = confusion_matrix(y_true, y_pred)
    cm_plot_labels = ['No Pothole', 'Pothole']
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=cm_plot_labels, yticklabels=cm_plot_labels)
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

    # Print classification report
    print('Classification Report')
    target_names = ['No Pothole', 'Pothole']
    print(classification_report(y_true, y_pred, target_names=target_names))

plot_confusion_matrix()
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 17s 730ms/step
# Classification Report
#               precision    recall  f1-score   support
#
#   No Pothole       0.50      0.51      0.50       352
#      Pothole       0.47      0.47      0.47       329
#
#     accuracy                           0.49       681
#    macro avg       0.49      0.49      0.49       681
# weighted avg       0.49      0.49      0.49       681

# %%
print(f"Final Training Accuracy: {history.history['accuracy'][-1]}")
print(f"Final Validation Accuracy: {history.history['val_accuracy'][-1]}")
print(f"Final Training Loss: {history.history['loss'][-1]}")
print(f"Final Validation Loss: {history.history['val_loss'][-1]}")
# Out:
# Final Training Accuracy: 0.9993342161178589
# Final Validation Accuracy: 0.9940476417541504
# Final Training Loss: 0.0019180149538442492
# Final Validation Loss: 0.035965584218502045

# %%
# Predict example images
predict_and_draw('/content/drive/MyDrive/phdimages/test/test pothole 1.jpg')
predict_and_draw('/content/drive/MyDrive/phdimages/test/test pothole 2.jpg')
predict_and_draw('/content/drive/MyDrive/phdimages/test/test pothole 3.jpg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 640ms/step
# Pothole detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step
# Pothole detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step
# No Pothole detected.
